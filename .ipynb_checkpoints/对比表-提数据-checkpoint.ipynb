# %%
import pandas as pd

# %%
df1 = pd.read_excel('phone.xlsx',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/lp/b1b2xb0s28x5mxn0gv6b40zm0000gn/T/ipykernel_7250/2563992142.py in <module>
# ----> 1 df1 = pd.read_excel('phone.xlsx',index_col=0)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'phone.xlsx'

# %%
df2 = pd.read_excel('data.xls', index_col=0)

# %%
df2
# Out:
#               tel
# name
# 文刚    13881518831
# 杨福平   18280693866
# 杨兴明   18113257962

# %%
df1.columns
# Out:
# Index(['legal_person', 'zhucedizhi', 'new_nianbao', 'tel', 'other_tel'], dtype='object')

# %%
df2.iloc[0]
# Out:
# tel    13881518831
# Name: 文刚, dtype: int64

# %%
df2.iloc[2,0]
# Out:
# '杨兴明'

# %%
df2.iloc[2,1]
# Out:
# 18113257962

# %%
len(df2)
# Out:
# 3

# %%
df1['tel'].dtpye
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lp/b1b2xb0s28x5mxn0gv6b40zm0000gn/T/ipykernel_88485/970416908.py in <module>
# ----> 1 df1['tel'].dtpye
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'dtpye'

# %%
df1[df1['tel'].isin(['18113257962'])]
# Out:
#           legal_person      zhucedizhi new_nianbao          tel  \
# company
# 会理县怀烯家庭农场          杨兴明  会理县通安镇通宝村1组71号    通安镇通宝村1组  18113257962
#
#                          other_tel
# company
# 会理县怀烯家庭农场  18113257962;18113257926

# %%
tel_2 = df2['tel'].astype(str).tolist()
tel_2
# Out:
# ['13881518831', '18280693866', '18113257962']

# %%
df3 = df1[df1['tel'].isin(tel_2)]

# %%
df3
# Out:
#           legal_person      zhucedizhi new_nianbao          tel  \
# company
# 会理县怀烯家庭农场          杨兴明  会理县通安镇通宝村1组71号    通安镇通宝村1组  18113257962
#
#                          other_tel
# company
# 会理县怀烯家庭农场  18113257962;18113257926

# %%
df3.to_excel('tb.xlsx', sheet_name='tb1')

# %%
def function(a, b):
    if a == b:
        return 1
    else:
        return 0

# %%
df['bool'] = df2.apply(lambda x: function(df2['电话号码'],df1['电话'], axis = 1 ))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/lp/b1b2xb0s28x5mxn0gv6b40zm0000gn/T/ipykernel_99243/245023787.py in <module>
# ----> 1 df['bool'] = df2.apply(lambda x: function(df2['电话号码'],df1['电话'], axis = 1 ))
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8739             kwargs=kwargs,
#    8740         )
# -> 8741         return op.apply()
#    8742
#    8743     def applymap(
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /var/folders/lp/b1b2xb0s28x5mxn0gv6b40zm0000gn/T/ipykernel_99243/245023787.py in <lambda>(x)
# ----> 1 df['bool'] = df2.apply(lambda x: function(df2['电话号码'],df1['电话'], axis = 1 ))
#
# TypeError: function() got an unexpected keyword argument 'axis'

# %%
df = pd.concat([df1, df2], axis=1)

# %%
df['result'] = np.where(df['电话'] == df['电话号码'], 'True', 'False')
print(df.loc[df['result'] == 'True'])
# Out:
# Empty DataFrame
# Columns: [法定代表人, 注册地址, 最新年报地址, 电话, 其他电话, 姓名, 电话号码, result]
# Index: []
